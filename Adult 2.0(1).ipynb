# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')
data=pd.read_csv(r"C:\Users\asus\Downloads\adult\adult.data",header=None,delimiter=' *, *',engine='python')
data
# Out:
#        0                 1       2           3   4                   5   \
# 0      39         State-gov   77516   Bachelors  13       Never-married
# 1      50  Self-emp-not-inc   83311   Bachelors  13  Married-civ-spouse
# 2      38           Private  215646     HS-grad   9            Divorced
# 3      53           Private  234721        11th   7  Married-civ-spouse
# 4      28           Private  338409   Bachelors  13  Married-civ-spouse
# ...    ..               ...     ...         ...  ..                 ...
# 32556  27           Private  257302  Assoc-acdm  12  Married-civ-spouse
# 32557  40           Private  154374     HS-grad   9  Married-civ-spouse
# 32558  58           Private  151910     HS-grad   9             Widowed
# 32559  22           Private  201490     HS-grad   9       Never-married
# 32560  52      Self-emp-inc  287927     HS-grad   9  Married-civ-spouse
#
#                       6              7      8       9      10  11  12  \
# ...

# %%
data
# Out:
#        0                 1       2           3   4                   5   \
# 0      39         State-gov   77516   Bachelors  13       Never-married
# 1      50  Self-emp-not-inc   83311   Bachelors  13  Married-civ-spouse
# 2      38           Private  215646     HS-grad   9            Divorced
# 3      53           Private  234721        11th   7  Married-civ-spouse
# 4      28           Private  338409   Bachelors  13  Married-civ-spouse
# ...    ..               ...     ...         ...  ..                 ...
# 32556  27           Private  257302  Assoc-acdm  12  Married-civ-spouse
# 32557  40           Private  154374     HS-grad   9  Married-civ-spouse
# 32558  58           Private  151910     HS-grad   9             Widowed
# 32559  22           Private  201490     HS-grad   9       Never-married
# 32560  52      Self-emp-inc  287927     HS-grad   9  Married-civ-spouse
#
#                       6              7      8       9      10  11  12  \
# ...

# %%
data.columns=['age','workclass','fnlwgt','education','education_num','marital_status','occupation','relationship','race','sex','capital_gain','capital_loss','hours_per_week','native_country','income']
data
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
data.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
data1=data.describe(include='all')
data1
# Out:
#                  age workclass        fnlwgt education  education_num  \
# count   32561.000000     32561  3.256100e+04     32561   32561.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581647       NaN  1.897784e+05       NaN      10.080679
# std        13.640433       NaN  1.055500e+05       NaN       2.572720
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#             marital_status      occupation relationship   race    sex  \
# ...

# %%
for value in ['native_country','income','sex','race','relationship','occupation','marital_status','workclass','education']:
    print(value,":",data[value].unique())
# Out:
# native_country : ['United-States' 'Cuba' 'Jamaica' 'India' '?' 'Mexico' 'South'
#  'Puerto-Rico' 'Honduras' 'England' 'Canada' 'Germany' 'Iran'
#  'Philippines' 'Italy' 'Poland' 'Columbia' 'Cambodia' 'Thailand' 'Ecuador'
#  'Laos' 'Taiwan' 'Haiti' 'Portugal' 'Dominican-Republic' 'El-Salvador'
#  'France' 'Guatemala' 'China' 'Japan' 'Yugoslavia' 'Peru'
#  'Outlying-US(Guam-USVI-etc)' 'Scotland' 'Trinadad&Tobago' 'Greece'
#  'Nicaragua' 'Vietnam' 'Hong' 'Ireland' 'Hungary' 'Holand-Netherlands']
# income : ['<=50K' '>50K']
# sex : ['Male' 'Female']
# race : ['White' 'Black' 'Asian-Pac-Islander' 'Amer-Indian-Eskimo' 'Other']
# relationship : ['Not-in-family' 'Husband' 'Wife' 'Own-child' 'Unmarried' 'Other-relative']
# occupation : ['Adm-clerical' 'Exec-managerial' 'Handlers-cleaners' 'Prof-specialty'
#  'Other-service' 'Sales' 'Craft-repair' 'Transport-moving'
#  'Farming-fishing' 'Machine-op-inspct' 'Tech-support' '?'
#  'Protective-serv' 'Armed-Forces' 'Priv-house-serv']
# ...

# %%
for i in ['native_country']:
    data[i].replace(['?'],data1[i][2],inplace=True)

# %%
for i in ['occupation']:
    data[i].replace(['?'],data1[i][2],inplace=True)

# %%
for i in ['workclass']:
    data[i].replace(['?'],data1[i][2],inplace=True)

# %%
for value in ['native_country','income','sex','race','relationship','occupation','marital_status','workclass','education']:
    print(value,":",data[value].unique())
# Out:
# native_country : ['United-States' 'Cuba' 'Jamaica' 'India' 'Mexico' 'South' 'Puerto-Rico'
#  'Honduras' 'England' 'Canada' 'Germany' 'Iran' 'Philippines' 'Italy'
#  'Poland' 'Columbia' 'Cambodia' 'Thailand' 'Ecuador' 'Laos' 'Taiwan'
#  'Haiti' 'Portugal' 'Dominican-Republic' 'El-Salvador' 'France'
#  'Guatemala' 'China' 'Japan' 'Yugoslavia' 'Peru'
#  'Outlying-US(Guam-USVI-etc)' 'Scotland' 'Trinadad&Tobago' 'Greece'
#  'Nicaragua' 'Vietnam' 'Hong' 'Ireland' 'Hungary' 'Holand-Netherlands']
# income : ['<=50K' '>50K']
# sex : ['Male' 'Female']
# race : ['White' 'Black' 'Asian-Pac-Islander' 'Amer-Indian-Eskimo' 'Other']
# relationship : ['Not-in-family' 'Husband' 'Wife' 'Own-child' 'Unmarried' 'Other-relative']
# occupation : ['Adm-clerical' 'Exec-managerial' 'Handlers-cleaners' 'Prof-specialty'
#  'Other-service' 'Sales' 'Craft-repair' 'Transport-moving'
#  'Farming-fishing' 'Machine-op-inspct' 'Tech-support' 'Protective-serv'
#  'Armed-Forces' 'Priv-house-serv']
# ...

# %%
data.shape
# Out:
# (32561, 15)

# %%
data
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
data['capital_gain'].unique()
# Out:
# array([ 2174,     0, 14084,  5178,  5013,  2407, 14344, 15024,  7688,
#        34095,  4064,  4386,  7298,  1409,  3674,  1055,  3464,  2050,
#         2176,   594, 20051,  6849,  4101,  1111,  8614,  3411,  2597,
#        25236,  4650,  9386,  2463,  3103, 10605,  2964,  3325,  2580,
#         3471,  4865, 99999,  6514,  1471,  2329,  2105,  2885, 25124,
#        10520,  2202,  2961, 27828,  6767,  2228,  1506, 13550,  2635,
#         5556,  4787,  3781,  3137,  3818,  3942,   914,   401,  2829,
#         2977,  4934,  2062,  2354,  5455, 15020,  1424,  3273, 22040,
#         4416,  3908, 10566,   991,  4931,  1086,  7430,  6497,   114,
#         7896,  2346,  3418,  3432,  2907,  1151,  2414,  2290, 15831,
#        41310,  4508,  2538,  3456,  6418,  1848,  3887,  5721,  9562,
#         1455,  2036,  1831, 11678,  2936,  2993,  7443,  6360,  1797,
#         1173,  4687,  6723,  2009,  6097,  2653,  1639, 18481,  7978,
#         2387,  5060], dtype=int64)

# %%
data['workclass'].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
plt.figure(figsize=(15, 8))
sns.countplot(x=data.native_country, hue=data.income)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.countplot(x=data.workclass, hue=data.income)
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.countplot(x=data.occupation, hue=data.income)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.countplot(x=data.education, hue=data.income)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=data.race,hue=data.income)
plt.show()

# %%
sns.countplot(x=data.relationship,hue=data.income)
plt.show()

# %%
sns.countplot(x=data.sex,hue=data.income)
plt.show()

# %%
sns.distplot(data.native_country[data.income== 0])
sns.distplot(data.native_country[data.income== 1])
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=data.marital_status, hue=data.income)

plt.xticks(rotation=90)

plt.show()

# %%
sns.scatterplot(x=data.income,y=data.capital_loss,hue=data.income)
plt.show()

# %%
sns.scatterplot(x=data.income,y=data.capital_gain,hue=data.income)
plt.show()

# %%
data['education_num'].unique()
# Out:
# array([13,  9,  7, 14,  5, 10, 12, 11,  4, 16, 15,  3,  6,  2,  1,  8],
#       dtype=int64)

# %%
data
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
sns.distplot(data.age[data.income==0],label='<=50K')
sns.distplot(data.age[data.income==1],label='>50k')
plt.legend()
plt.show()

# %%
sns.kdeplot(data.education_num[data.income==0],label='<=50K')
sns.kdeplot(data.education_num[data.income==1],label='>50K')
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data.workclass=le.fit_transform(data.workclass)
le1=LabelEncoder()
data.education=le1.fit_transform(data.education)
le2=LabelEncoder()
data.marital_status=le2.fit_transform(data.marital_status)
le3=LabelEncoder()
data.native_country=le3.fit_transform(data.native_country)
le4=LabelEncoder()
data.occupation=le4.fit_transform(data.occupation)
le5=LabelEncoder()
data.relationship=le5.fit_transform(data.relationship)
le6=LabelEncoder()
data.race=le6.fit_transform(data.race)
le7=LabelEncoder()
data.sex=le7.fit_transform(data.sex)
le8=LabelEncoder()
data.income=le8.fit_transform(data.income)

# %%
sns.boxplot(x=data.income,y=data.education_num,hue=data.income)
plt.show()

# %%
sns.distplot(data.hours_per_week[data.income==0],label='<=50K')
sns.distplot(data.hours_per_week[data.income==1],label='>50k')
plt.legend()
plt.show()

# %%
sns.kdeplot(data.capital_loss[data.income==0],label='<=50K')
sns.kdeplot(data.capital_loss[data.income==1],label='>50K')
plt.legend()
plt.show()

# %%
sns.kdeplot(data.capital_gain[data.income==0],label='<=50K')
sns.kdeplot(data.capital_gain[data.income==1],label='>50K')
plt.legend()
plt.show()

# %%
data1=data.drop(['capital_gain'],axis=1)

# %%
data1
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          6   77516          9             13               4
# 1       50          5   83311          9             13               2
# 2       38          3  215646         11              9               0
# 3       53          3  234721          1              7               2
# 4       28          3  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          3  257302          7             12               2
# 32557   40          3  154374         11              9               2
# 32558   58          3  151910         11              9               6
# 32559   22          3  201490         11              9               4
# 32560   52          4  287927         11              9               2
#
#        occupation  relationship  race  sex  capital_loss  hours_per_week  \
# ...

# %%
d=data1.corr()

# %%
plt.figure(figsize=(15,8))
sns.heatmap(d,annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
ip=data1.drop(['income'],axis=1)

# %%
op=data1['income']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(ip,op,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
alg1=LogisticRegression()
alg1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
yp=alg1.predict(x_test)

# %%
df=pd.DataFrame({'y':list(y_test),'prediction':yp})

# %%
df
# Out:
#       y  prediction
# 0     0           1
# 1     1           0
# 2     0           0
# 3     0           0
# 4     0           0
# ...  ..         ...
# 6508  0           0
# 6509  1           1
# 6510  0           0
# 6511  0           0
# 6512  0           0
#
# [6513 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm=confusion_matrix(y_test,yp)
cm
# Out:
# array([[4609,  347],
#        [ 911,  646]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
acc=accuracy_score(y_test,yp)
recall=recall_score(y_test,yp)
f1=f1_score(y_test,yp)
prec=precision_score(y_test,yp)

# %%
print(acc)
print(recall)
print(prec)
print(f1)
# Out:
# 0.8068478427759865
# 0.41490044958253053
# 0.6505538771399798
# 0.5066666666666667

# %%
from sklearn.neighbors import KNeighborsClassifier
alg2=KNeighborsClassifier(n_neighbors=5)
alg2.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
yp2=alg2.predict(x_test)
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
recall2=recall_score(y_test,yp2)
f12=f1_score(y_test,yp2)
prec2=precision_score(y_test,yp2)
acc2=accuracy_score(y_test,yp2)

# %%
print(acc2)
print(recall2)
print(prec2)
print(f12)
# Out:
# 0.8146783356364194
# 0.5780346820809249
# 0.6206896551724138
# 0.5986032590621883

# %%
from sklearn.naive_bayes import GaussianNB
clf=GaussianNB()
clf.fit(x_train,y_train)
yp1=clf.predict(x_test)

# %%
from sklearn import metrics
recall=metrics.recall_score(y_test,yp1)
accuracy=metrics.accuracy_score(y_test,yp1)
print(recall)
print(accuracy)
# Out:
# 0.6628131021194605
# 0.786273606632888

# %%
from sklearn import svm
salg=svm.SVC(kernel='rbf',C=1000,gamma=0.01)
salg.fit(x_train,y_train)
yp11=salg.predict(x_test)

# %%
from sklearn import metrics
recall=metrics.recall_score(y_test,yp11)
accuracy=metrics.accuracy_score(y_test,yp11)
print(recall)
print(accuracy)
# Out:
# 0.4964675658317277
# 0.8288039306003377

# %%
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier(criterion='entropy')

clf = clf.fit(x_train,y_train)

y_pred=clf.predict(x_test)

from sklearn import metrics
accuracy2=metrics.accuracy_score(y_test,y_pred)
recall2=metrics.recall_score(y_test,y_pred)
print(recall2)
print(accuracy2)
# Out:
# 0.5305073859987155
# 0.7749117150314755

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(criterion='entropy',random_state=0)

clf = clf.fit(x_train,y_train)

y_pred=clf.predict(x_test)

from sklearn import metrics
cm=metrics.confusion_matrix(y_test,yp)

accuracy2=metrics.accuracy_score(y_test,yp)
recall2=metrics.recall_score(y_test,y_pred)
print(recall2)
print(accuracy2)
# Out:
# 0.5305073859987155
# 0.8068478427759865
